# %% [markdown]
# # Create an Audiobook from a PDF
# ## This task tests your ability to apply Text to Speech conversion and Extraction of Text from PDF files in the creation of an audiobook from a PDF file

# %% [markdown]
# ### Steps
# - Extract text from PDF file
# - Clean the text
# - Convert the text into speech
# - Save the speech
# - Play the speech

# %% [markdown]
# ## 1. Extract text from PDF
# - Use PyPDF2

# %% [markdown]
# ### Install the library

# %%
! pip install PyPDF2
# Out:
# ...
#   Created wheel for PyPDF2: filename=PyPDF2-1.26.0-py3-none-any.whl size=61101 sha256=6e278ba6bf5b366d22ea4a622187c26c532fcfc893c2ba3d6cfa0adce1d126c0
#   Stored in directory: c:\users\sarah\appdata\local\pip\cache\wheels\b1\1a\8f\a4c34be976825a2f7948d0fa40907598d69834f8ab5889de11
# Successfully built PyPDF2
# ...

# %% [markdown]
# ### Import the library

# %%
import PyPDF2 as pp

# %% [markdown]
# ### Extract the text

# %%
file_name = "sample.pdf"

# %%
def get_text(file_name):
    file = pp.PdfFileReader(file_name)
    page_num = file.getNumPages()
    page_text= ""
    for p in range(0,page_num):
        page_text += file.getPage(p).extractText()
    return page_text

# %%
page_text = get_text(file_name)

# %% [markdown]
# ### Print the extracted text

# %%
print(page_text)
# Out:
#  A Simple PDF File  This is a small demonstration .pdf file -  just for use in the Virtual Mechanics tutorials. More text. And more  text. And more text. And more text. And more text.  And more text. And more text. And more text. And more text. And more  text. And more text. Boring, zzzzz. And more text. And more text. And  more text. And more text. And more text. And more text. And more text.  And more text. And more text.  And more text. And more text. And more text. And more text. And more  text. And more text. And more text. Even more. Continued on page 2 ... Simple PDF File 2  ...continued from page 1. Yet more text. And more text. And more text.  And more text. And more text. And more text. And more text. And more  text. Oh, how boring typing this stuff. But not as boring as watching  paint dry. And more text. And more text. And more text. And more text.  Boring.  More, a little more text. The end, and just as well.

# %% [markdown]
# ## 2. Convert the Text into Speech
# - Use **pyttsx3** OR **gTTS**

# %% [markdown]
# ### Import the library

# %%
from gtts import gTTS

# %% [markdown]
# ### Initialize a Speaker object and convert text

# %%
language = 'en'
page_speech = gTTS(text=page_text, lang = language, slow = False)

# %% [markdown]
# ### Save the audio

# %%
page_speech.save('pdf_speech.wav')

# %%
import IPython
IPython.display.display(IPython.display.Audio('pdf_speech.wav'))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
